# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
boston = pd.read_excel('datasets/Boston Benchmarking Ordinance.xlsx', sheetname=2)
chicago = pd.read_excel('datasets/Chicago Benchmarking Ordinance.xlsx', sheetname=1)
minneapolis = pd.read_excel('datasets/Minneapolis Benchmarking Ordinance.xlsx', sheetname=3)
newyorkcity = pd.read_excel('datasets/New York Benchmarking Ordinance (excl. audit data).xlsx', sheetname=2)
philadelphia = pd.read_excel('datasets/Philadelphia Benchmarking Ordinance.xlsx', sheetname=1)
sanfrancisco = pd.read_excel('datasets/San Francisco Benchmarking Ordinance.xls', sheetname=1)  # sf doesn't have type labels
washingtondc = pd.read_excel('datasets/Washington D.C. Benchmarking Ordinance.xlsx', sheetname=4)  # missing a lot of labels

# %%
chi = chicago.loc[chicago['Property Type'] == 'Hospital (General Medical & Surgical)']
bos = boston.loc[boston['Property Type'] == 'Hospital (General Medical & Surgical)']
minn = minneapolis.loc[minneapolis['Property Type'] == 'Hospital (General Medical & Surgical)']
nyc = newyorkcity.loc[newyorkcity['Property Type'] == 'Hospital (General Medical & Surgical)']
phi = philadelphia.loc[philadelphia['Property Type'] == 'Hospital (General Medical & Surgical)']
wdc = washingtondc.loc[washingtondc['Property Type'] == 'Hospital (General Medical & Surgical)']

# %%
# dataframe with all data
all_data = pd.concat([boston,chicago,minneapolis,newyorkcity,philadelphia,sanfrancisco,washingtondc])

# dataframe with all hospitals
all_hospitals = pd.concat([chi,bos,minn,nyc,phi,wdc])

# %%
# plotting hospital GHGs by city
fig, ax = plt.subplots(figsize=(16,6))
sns.set_style("whitegrid")
GHG_swarm = sns.swarmplot(x='City', y='Total GHG Emissions (MtCO2e)', data=all_hospitals, ax=ax)

# %%
# plotting hospital source EUI by city
# Boston doesn't have source EUI
fig, ax = plt.subplots(figsize=(16,6))
all_hospitals_no_boston = pd.concat([chi,minn,nyc,phi,wdc])
sns.set_style('whitegrid')
source_EUI_swarm = sns.swarmplot(x='City', y='Source EUI (kBtu/ft^2)', data=all_hospitals_no_boston, ax=ax)

# %%
# plotting source EUI by building type
all_data_no_boston = pd.concat([chicago,minneapolis,newyorkcity,philadelphia,sanfrancisco,washingtondc])
fig, ax = plt.subplots(figsize=(16,6))
sns.set_style("whitegrid")
#GHG_swarm = sns.swarmplot(x='Property Type', y='Source EUI (kBtu/ft^2)', data=all_data_no_boston, ax=ax)

# %%
#print all_data_no_boston['Property Type'].value_counts
prop_types = pd.Series(all_data_no_boston['Property Type'])
print prop_types
# Out:
# 0                                 K-12 School
# 1                                 K-12 School
# 2                           Convention Center
# 3                                 K-12 School
# 4                                 K-12 School
# 5                                 K-12 School
# 6       Hospital (General Medical & Surgical)
# 7                                 K-12 School
# 8                                 K-12 School
# 9                          College/University
# 10                         College/University
# 11                                K-12 School
# 12                         College/University
# 13                                K-12 School
# 14      Hospital (General Medical & Surgical)
# 15                                     Office
# 16      Hospital (General Medical & Surgical)
# 17      Hospital (General Medical & Surgical)
# 18      Hospital (General Medical & Surgical)
# 19                 Ambulatory Surgical Center
# 20                                 Laboratory
# 21                         College/University
# 22                                 Laboratory
# 23                                     Museum
# 24                                    Library
# 25                                K-12 School
# 26                                K-12 School
# 27      Hospital (General Medical & Surgical)
# 28                                K-12 School
# 29      Hospital (General Medical & Surgical)
#                         ...
# 1562                                   Office
# 1563                      Multifamily Housing
# 1564                      Multifamily Housing
# 1565                      Multifamily Housing
# 1566                      Multifamily Housing
# 1567                      Multifamily Housing
# 1568                      Multifamily Housing
# 1569                      Multifamily Housing
# 1570                      Multifamily Housing
# 1571                      Multifamily Housing
# 1572                      Multifamily Housing
# 1573                      Multifamily Housing
# 1574                      Multifamily Housing
# 1575                      Multifamily Housing
# 1576                      Multifamily Housing
# 1577               Non-Refrigerated Warehouse
# 1578                      Multifamily Housing
# 1579                      Multifamily Housing
# 1580                      Multifamily Housing
# 1581                      Multifamily Housing
# 1582                      Multifamily Housing
# 1583                      Multifamily Housing
# 1584                      Multifamily Housing
# 1585                      Multifamily Housing
# 1586                 Residence Hall/Dormitory
# 1587                 Residence Hall/Dormitory
# 1588                       College/University
# 1589                       College/University
# 1590                                   Office
# 1591                         Worship Facility
# Name: Property Type, dtype: object
